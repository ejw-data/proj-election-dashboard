# %%
# !pip install simplejson

# %%
# Dependencies
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
import json
import simplejson

# %%
# Database Setup
engine = create_engine('postgresql://postgres:postgres@localhost:5432/election_db')

# %%
# Reflect an existing database into a new model
Base = automap_base()

# Reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table
Election = Base.classes.districts

# %%
# Create session and query
session = Session(engine)
elections = session.query(Election).all()

# %%
column_names_list = Base.classes.districts.__table__.columns.keys()

# %%
results = []
for u in elections:
    temp = u.__dict__
    del temp['_sa_instance_state']
    results.append(temp)

# %%
results
# Out:
# [{'last_name': 'Byrne',
#   'votepercent_president2004_democrat': 35.0,
#   'acs_ba_rank': 308.0,
#   'votetotal2016_house': 215893.0,
#   'votepercent_president2016_republican': 63.5,
#   'acs_population_adult_white': 68.7,
#   'qvote_president_republican': 192634.0,
#   'house2_party2012_dem': 0.0,
#   'vote_house2014_other': 198.0,
#   'first_elected': 2016,
#   'votepercent_president2004_republican': 64.0,
#   'acs_ba_white': 27.7,
#   'vote_house2016_democrat': 0.0,
#   'votepercent_president2012_democrat': 37.4,
#   'acs_population_adult_black': 26.5,
#   'votetotal_president2012': 298837.0,
#   'house2_party2012_rep': 196374.0,
#   'birth_year': 1955,
#   'votepercent_president2000_democrat': 38.0,
#   'acs_ba_white_rank': 303.0,
#   'vote_house2016_republican': 208083.0,
#   'id': 1,
#   'votepercent_president2012_republican': 61.8,
#   'acs_population_adult_latino': 1.8,
#   'vote_president2012_democrat': 111735.0,
#   'acs_population_total': 688770.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 60.0,
#   'acs_medianincome': 47083.0,
#   'vote_house2016_other': 7810.0,
#   'votepercent_president2008_democrat': 38.5,
#   'district': 'Alabama 1st',
#   'acs_population_adult_asianpacificislander': 0.9,
#   'vote_president2012_republican': 184786.0,
#   'acs_votingagepopulation_total': 526450.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 31.7,
#   'acs_medianincome_rank': 350.0,
#   'vote_total2014_house': 152234.0,
#   'code': 'AL-01',
#   'votepercent_president2008_republican': 60.9,
#   'acs_population_adult_native': 1.0,
#   'votetotal_president2008': 301556.0,
#   'two_party2012_rep': 100.0,
#   'religion': 'Christian - Episcopalian',
#   'votepercent2014_house_republican': 68.2,
#   'noncollege_white_share': 49.6,
#   'vote_house2014_democrat': 48278.0,
#   'rvotepercent_house_democrat': 0.0,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.1,
#   'vote_president2008_democrat': 115975.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 0.0,
#   'tvotetotal_president': 303478.0,
#   'vote_house2014_republican': 103758.0,
#   'first_name': 'Bradley',
#   'rvotepercent_house_republican': 96.4,
#   'acs_bachelordegree_age25plus': 24.0,
#   'qvote_president_democrat': 103364.0,
#   'vote_president2008_republican': 183753.0,
#   'votepercent_president2016_democrat': 34.1},
#  {'last_name': 'Roby',
#   'votepercent_president2004_democrat': 33.0,
#   'acs_ba_rank': 354.0,
#   'votetotal2016_house': 276584.0,
#   'votepercent_president2016_republican': 64.9,
#   'acs_population_adult_white': 66.1,
#   'qvote_president_republican': 185505.0,
#   'house2_party2012_dem': 103092.0,
#   'vote_house2014_other': 157.0,
#   'first_elected': 2010,
#   'votepercent_president2004_republican': 67.0,
#   'acs_ba_white': 24.2,
#   'vote_house2016_democrat': 112089.0,
#   'votepercent_president2012_democrat': 36.4,
#   'acs_population_adult_black': 29.9,
#   'votetotal_president2012': 289864.0,
#   'house2_party2012_rep': 180591.0,
#   'birth_year': 1976,
#   'votepercent_president2000_democrat': 38.0,
#   'acs_ba_white_rank': 371.0,
#   'vote_house2016_republican': 134886.0,
#   'id': 2,
#   'votepercent_president2012_republican': 62.9,
#   'acs_population_adult_latino': 1.8,
#   'vote_president2012_democrat': 105572.0,
#   'acs_population_total': 671185.0,
#   'gender': 'Woman',
#   'votepercent_president2000_republican': 61.0,
#   'acs_medianincome': 42035.0,
#   'vote_house2016_other': 29609.0,
#   'votepercent_president2008_democrat': 35.0,
#   'district': 'Alabama 2nd',
#   'acs_population_adult_asianpacificislander': 0.7,
#   'vote_president2012_republican': 182287.0,
#   'acs_votingagepopulation_total': 514995.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 32.6,
#   'acs_medianincome_rank': 396.0,
#   'vote_total2014_house': 167952.0,
#   'code': 'AL-02',
#   'votepercent_president2008_republican': 64.5,
#   'acs_population_adult_native': 0.4,
#   'votetotal_president2008': 288807.0,
#   'two_party2012_rep': 63.7,
#   'religion': 'Christian - Presbyterian',
#   'votepercent2014_house_republican': 67.3,
#   'noncollege_white_share': 50.1,
#   'vote_house2014_democrat': 54692.0,
#   'rvotepercent_house_democrat': 40.5,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.1,
#   'vote_president2008_democrat': 101076.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 36.3,
#   'tvotetotal_president': 285664.0,
#   'vote_house2014_republican': 113103.0,
#   'first_name': 'Martha',
#   'rvotepercent_house_republican': 48.8,
#   'acs_bachelordegree_age25plus': 21.8,
#   'qvote_president_democrat': 94299.0,
#   'vote_president2008_republican': 186164.0,
#   'votepercent_president2016_democrat': 33.0},
#  {'last_name': 'Rogers',
#   'votepercent_president2004_democrat': 41.0,
#   'acs_ba_rank': 336.0,
#   'votetotal2016_house': 287104.0,
#   'votepercent_president2016_republican': 65.3,
#   'acs_population_adult_white': 71.4,
#   'qvote_president_republican': 188477.0,
#   'house2_party2012_dem': 98141.0,
#   'vote_house2014_other': 246.0,
#   'first_elected': 2002,
#   'votepercent_president2004_republican': 58.0,
#   'acs_ba_white': 23.7,
#   'vote_house2016_democrat': 94549.0,
#   'votepercent_president2012_democrat': 36.8,
#   'acs_population_adult_black': 25.1,
#   'votetotal_president2012': 280128.0,
#   'house2_party2012_rep': 175306.0,
#   'birth_year': 1958,
#   'votepercent_president2000_democrat': 47.0,
#   'acs_ba_white_rank': 380.0,
#   'vote_house2016_republican': 192164.0,
#   'id': 3,
#   'votepercent_president2012_republican': 62.3,
#   'acs_population_adult_latino': 1.7,
#   'vote_president2012_democrat': 103089.0,
#   'acs_population_total': 687545.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 52.0,
#   'acs_medianincome': 46544.0,
#   'vote_house2016_other': 391.0,
#   'votepercent_president2008_democrat': 36.6,
#   'district': 'Alabama 3rd',
#   'acs_population_adult_asianpacificislander': 0.7,
#   'vote_president2012_republican': 174465.0,
#   'acs_votingagepopulation_total': 532720.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 33.7,
#   'acs_medianincome_rank': 357.0,
#   'vote_total2014_house': 156620.0,
#   'code': 'AL-03',
#   'votepercent_president2008_republican': 62.6,
#   'acs_population_adult_native': 0.3,
#   'votetotal_president2008': 281951.0,
#   'two_party2012_rep': 64.1,
#   'religion': 'Christian - Baptist',
#   'votepercent2014_house_republican': 66.1,
#   'noncollege_white_share': 54.4,
#   'vote_house2014_democrat': 52816.0,
#   'rvotepercent_house_democrat': 32.9,
#   'party': 'Republican',
#   'acs_population_adult_other': 0.9,
#   'vote_president2008_democrat': 103221.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 35.9,
#   'tvotetotal_president': 288776.0,
#   'vote_house2014_republican': 103558.0,
#   'first_name': 'Mike',
#   'rvotepercent_house_republican': 66.9,
#   'acs_bachelordegree_age25plus': 22.8,
#   'qvote_president_democrat': 93300.0,
#   'vote_president2008_republican': 176434.0,
#   'votepercent_president2016_democrat': 32.3},
#  {'last_name': 'Aderholt',
#   'votepercent_president2004_democrat': 28.0,
#   'acs_ba_rank': 412.0,
#   'votetotal2016_house': 239444.0,
#   'votepercent_president2016_republican': 80.4,
#   'acs_population_adult_white': 88.8,
#   'qvote_president_republican': 233661.0,
#   'house2_party2012_dem': 69706.0,
#   'vote_house2014_other': 1921.0,
#   'first_elected': 1996,
#   'votepercent_president2004_republican': 71.0,
#   'acs_ba_white': 17.8,
#   'vote_house2016_democrat': 0.0,
#   'votepercent_president2012_democrat': 24.0,
#   'acs_population_adult_black': 6.9,
#   'votetotal_president2012': 274505.0,
#   'house2_party2012_rep': 199071.0,
#   'birth_year': 1965,
#   'votepercent_president2000_democrat': 37.0,
#   'acs_ba_white_rank': 426.0,
#   'vote_house2016_republican': 235925.0,
#   'id': 4,
#   'votepercent_president2012_republican': 74.8,
#   'acs_population_adult_latino': 1.8,
#   'vote_president2012_democrat': 65818.0,
#   'acs_population_total': 664720.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 61.0,
#   'acs_medianincome': 41110.0,
#   'vote_house2016_other': 3519.0,
#   'votepercent_president2008_democrat': 25.5,
#   'district': 'Alabama 4th',
#   'acs_population_adult_asianpacificislander': 0.5,
#   'vote_president2012_republican': 205423.0,
#   'acs_votingagepopulation_total': 510100.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 0.0,
#   'acs_medianincome_rank': 406.0,
#   'vote_total2014_house': 134752.0,
#   'code': 'AL-04',
#   'votepercent_president2008_republican': 73.3,
#   'acs_population_adult_native': 0.7,
#   'votetotal_president2008': 278483.0,
#   'two_party2012_rep': 74.1,
#   'religion': 'Christian - Congregationalist',
#   'votepercent2014_house_republican': 98.6,
#   'noncollege_white_share': 73.0,
#   'vote_house2014_democrat': 0.0,
#   'rvotepercent_house_democrat': 0.0,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.3,
#   'vote_president2008_democrat': 71095.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 25.9,
#   'tvotetotal_president': 290726.0,
#   'vote_house2014_republican': 132831.0,
#   'first_name': 'Robert',
#   'rvotepercent_house_republican': 98.5,
#   'acs_bachelordegree_age25plus': 17.0,
#   'qvote_president_democrat': 50722.0,
#   'vote_president2008_republican': 204123.0,
#   'votepercent_president2016_democrat': 17.4},
#  {'last_name': 'Brooks',
#   'votepercent_president2004_democrat': 39.0,
#   'acs_ba_rank': 191.0,
#   'votetotal2016_house': 308326.0,
#   'votepercent_president2016_republican': 64.7,
#   'acs_population_adult_white': 77.3,
#   'qvote_president_republican': 200571.0,
#   'house2_party2012_dem': 101772.0,
#   'vote_house2014_other': 39636.0,
#   'first_elected': 2010,
#   'votepercent_president2004_republican': 60.0,
#   'acs_ba_white': 31.0,
#   'vote_house2016_democrat': 102234.0,
#   'votepercent_president2012_democrat': 34.9,
#   'acs_population_adult_black': 17.1,
#   'votetotal_president2012': 297263.0,
#   'house2_party2012_rep': 189185.0,
#   'birth_year': 1954,
#   'votepercent_president2000_democrat': 44.0,
#   'acs_ba_white_rank': 250.0,
#   'vote_house2016_republican': 205647.0,
#   'id': 5,
#   'votepercent_president2012_republican': 63.9,
#   'acs_population_adult_latino': 2.2,
#   'vote_president2012_democrat': 103598.0,
#   'acs_population_total': 686530.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 54.0,
#   'acs_medianincome': 51690.0,
#   'vote_house2016_other': 445.0,
#   'votepercent_president2008_democrat': 36.3,
#   'district': 'Alabama 5th',
#   'acs_population_adult_asianpacificislander': 1.1,
#   'vote_president2012_republican': 189860.0,
#   'acs_votingagepopulation_total': 530085.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 0.0,
#   'acs_medianincome_rank': 274.0,
#   'vote_total2014_house': 154974.0,
#   'code': 'AL-05',
#   'votepercent_president2008_republican': 62.6,
#   'acs_population_adult_native': 0.6,
#   'votetotal_president2008': 294444.0,
#   'two_party2012_rep': 65.0,
#   'religion': 'Christian - Nondenominational',
#   'votepercent2014_house_republican': 74.4,
#   'noncollege_white_share': 53.3,
#   'vote_house2014_democrat': 0.0,
#   'rvotepercent_house_democrat': 33.2,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.6,
#   'vote_president2008_democrat': 107005.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 35.0,
#   'tvotetotal_president': 309937.0,
#   'vote_house2014_republican': 115338.0,
#   'first_name': 'Mo',
#   'rvotepercent_house_republican': 66.7,
#   'acs_bachelordegree_age25plus': 30.3,
#   'qvote_president_democrat': 97159.0,
#   'vote_president2008_republican': 184225.0,
#   'votepercent_president2016_democrat': 31.3},
#  {'last_name': 'Palmer',
#   'votepercent_president2004_democrat': 22.0,
#   'acs_ba_rank': 112.0,
#   'votetotal2016_house': 329306.0,
#   'votepercent_president2016_republican': 70.8,
#   'acs_population_adult_white': 81.8,
#   'qvote_president_republican': 233493.0,
#   'house2_party2012_dem': 88267.0,
#   'vote_house2014_other': 213.0,
#   'first_elected': 2014,
#   'votepercent_president2004_republican': 78.0,
#   'acs_ba_white': 38.2,
#   'vote_house2016_democrat': 83709.0,
#   'votepercent_president2012_democrat': 24.7,
#   'acs_population_adult_black': 14.4,
#   'votetotal_president2012': 314343.0,
#   'house2_party2012_rep': 219262.0,
#   'birth_year': 1954,
#   'votepercent_president2000_democrat': 25.0,
#   'acs_ba_white_rank': 156.0,
#   'vote_house2016_republican': 245313.0,
#   'id': 6,
#   'votepercent_president2012_republican': 74.3,
#   'acs_population_adult_latino': 1.6,
#   'vote_president2012_democrat': 77517.0,
#   'acs_population_total': 673110.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 74.0,
#   'acs_medianincome': 61413.0,
#   'vote_house2016_other': 284.0,
#   'votepercent_president2008_democrat': 25.0,
#   'district': 'Alabama 6th',
#   'acs_population_adult_asianpacificislander': 1.0,
#   'vote_president2012_republican': 233566.0,
#   'acs_votingagepopulation_total': 511790.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 23.7,
#   'acs_medianincome_rank': 165.0,
#   'vote_total2014_house': 178449.0,
#   'code': 'AL-06',
#   'votepercent_president2008_republican': 74.1,
#   'acs_population_adult_native': 0.2,
#   'votetotal_president2008': 313838.0,
#   'two_party2012_rep': 71.3,
#   'religion': 'Christian - Presbyterian',
#   'votepercent2014_house_republican': 76.2,
#   'noncollege_white_share': 50.5,
#   'vote_house2014_democrat': 42291.0,
#   'rvotepercent_house_democrat': 25.4,
#   'party': 'Republican',
#   'acs_population_adult_other': 0.9,
#   'vote_president2008_democrat': 78559.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 28.7,
#   'tvotetotal_president': 329849.0,
#   'vote_house2014_republican': 135945.0,
#   'first_name': 'Gary',
#   'rvotepercent_house_republican': 74.5,
#   'acs_bachelordegree_age25plus': 36.7,
#   'qvote_president_democrat': 86116.0,
#   'vote_president2008_republican': 232644.0,
#   'votepercent_president2016_democrat': 26.1},
#  {'last_name': 'Sewell',
#   'votepercent_president2004_democrat': 64.0,
#   'acs_ba_rank': 393.0,
#   'votetotal2016_house': 233028.0,
#   'votepercent_president2016_republican': 28.6,
#   'acs_population_adult_white': 35.6,
#   'qvote_president_republican': 83915.0,
#   'house2_party2012_dem': 232520.0,
#   'vote_house2014_other': 2212.0,
#   'first_elected': 2010,
#   'votepercent_president2004_republican': 35.0,
#   'acs_ba_white': 28.5,
#   'vote_house2016_democrat': 229330.0,
#   'votepercent_president2012_democrat': 72.4,
#   'acs_population_adult_black': 62.1,
#   'votetotal_president2012': 315244.0,
#   'house2_party2012_rep': 73835.0,
#   'birth_year': 1965,
#   'votepercent_president2000_democrat': 66.0,
#   'acs_ba_white_rank': 292.0,
#   'vote_house2016_republican': 0.0,
#   'id': 7,
#   'votepercent_president2012_republican': 27.1,
#   'acs_population_adult_latino': 1.1,
#   'vote_president2012_democrat': 228276.0,
#   'acs_population_total': 662645.0,
#   'gender': 'Woman',
#   'votepercent_president2000_republican': 33.0,
#   'acs_medianincome': 34664.0,
#   'vote_house2016_other': 3698.0,
#   'votepercent_president2008_democrat': 71.5,
#   'district': 'Alabama 7th',
#   'acs_population_adult_asianpacificislander': 0.4,
#   'vote_president2012_republican': 85488.0,
#   'acs_votingagepopulation_total': 513355.0,
#   'race_ethnicity': 'Black - African-American',
#   'votepercent2014_house_democrat': 98.4,
#   'acs_medianincome_rank': 431.0,
#   'vote_total2014_house': 135899.0,
#   'code': 'AL-07',
#   'votepercent_president2008_republican': 28.1,
#   'acs_population_adult_native': 0.1,
#   'votetotal_president2008': 315625.0,
#   'two_party2012_rep': 24.1,
#   'religion': 'Christian - Methodist',
#   'votepercent2014_house_republican': 0.0,
#   'noncollege_white_share': 25.4,
#   'vote_house2014_democrat': 133687.0,
#   'rvotepercent_house_democrat': 98.4,
#   'party': 'Democratic',
#   'acs_population_adult_other': 0.8,
#   'vote_president2008_democrat': 225642.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 75.9,
#   'tvotetotal_president': 293231.0,
#   'vote_house2014_republican': 0.0,
#   'first_name': 'Terri',
#   'rvotepercent_house_republican': 0.0,
#   'acs_bachelordegree_age25plus': 19.4,
#   'qvote_president_democrat': 204586.0,
#   'vote_president2008_republican': 88803.0,
#   'votepercent_president2016_democrat': 69.8},
#  {'last_name': 'Young',
#   'votepercent_president2004_democrat': 36.0,
#   'acs_ba_rank': 209.0,
#   'votetotal2016_house': 308198.0,
#   'votepercent_president2016_republican': 52.8,
#   'acs_population_adult_white': 67.9,
#   'qvote_president_republican': 163387.0,
#   'house2_party2012_dem': 82927.0,
#   'vote_house2014_other': 22563.0,
#   'first_elected': 1973,
#   'votepercent_president2004_republican': 61.0,
#   'acs_ba_white': 36.7,
#   'vote_house2016_democrat': 111019.0,
#   'votepercent_president2012_democrat': 41.2,
#   'acs_population_adult_black': 3.1,
#   'votetotal_president2012': 297625.0,
#   'house2_party2012_rep': 185296.0,
#   'birth_year': 1933,
#   'votepercent_president2000_democrat': 28.0,
#   'acs_ba_white_rank': 174.0,
#   'vote_house2016_republican': 155088.0,
#   'id': 8,
#   'votepercent_president2012_republican': 55.3,
#   'acs_population_adult_latino': 5.4,
#   'vote_president2012_democrat': 122640.0,
#   'acs_population_total': 712745.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 59.0,
#   'acs_medianincome': 76440.0,
#   'vote_house2016_other': 42091.0,
#   'votepercent_president2008_democrat': 38.1,
#   'district': 'Alaska At-Large',
#   'acs_population_adult_asianpacificislander': 5.0,
#   'vote_president2012_republican': 164676.0,
#   'acs_votingagepopulation_total': 527810.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 41.0,
#   'acs_medianincome_rank': 65.0,
#   'vote_total2014_house': 279725.0,
#   'code': 'AK-00',
#   'votepercent_president2008_republican': 59.7,
#   'acs_population_adult_native': 13.0,
#   'votetotal_president2008': 324467.0,
#   'two_party2012_rep': 69.1,
#   'religion': 'Christian - Episcopalian',
#   'votepercent2014_house_republican': 51.0,
#   'noncollege_white_share': 42.9,
#   'vote_house2014_democrat': 114596.0,
#   'rvotepercent_house_democrat': 36.0,
#   'party': 'Republican',
#   'acs_population_adult_other': 5.6,
#   'vote_president2008_democrat': 123594.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 30.9,
#   'tvotetotal_president': 309407.0,
#   'vote_house2014_republican': 142566.0,
#   'first_name': 'Don',
#   'rvotepercent_house_republican': 50.3,
#   'acs_bachelordegree_age25plus': 29.6,
#   'qvote_president_democrat': 116454.0,
#   'vote_president2008_republican': 193841.0,
#   'votepercent_president2016_democrat': 37.6},
#  {'last_name': "O'Halleran",
#   'votepercent_president2004_democrat': 46.0,
#   'acs_ba_rank': 304.0,
#   'votetotal2016_house': 280710.0,
#   'votepercent_president2016_republican': 47.7,
#   'acs_population_adult_white': 56.1,
#   'qvote_president_republican': 135928.0,
#   'house2_party2012_dem': 122774.0,
#   'vote_house2014_other': 0.0,
#   'first_elected': 2016,
#   'votepercent_president2004_republican': 54.0,
#   'acs_ba_white': 34.2,
#   'vote_house2016_democrat': 142219.0,
#   'votepercent_president2012_democrat': 47.9,
#   'acs_population_adult_black': 2.2,
#   'votetotal_president2012': 260056.0,
#   'house2_party2012_rep': 113594.0,
#   'birth_year': 1946,
#   'votepercent_president2000_democrat': 46.0,
#   'acs_ba_white_rank': 199.0,
#   'vote_house2016_republican': 121745.0,
#   'id': 9,
#   'votepercent_president2012_republican': 50.4,
#   'acs_population_adult_latino': 17.1,
#   'vote_president2012_democrat': 124550.0,
#   'acs_population_total': 709770.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 51.0,
#   'acs_medianincome': 50537.0,
#   'vote_house2016_other': 16746.0,
#   'votepercent_president2008_democrat': 47.8,
#   'district': 'Arizona 1st',
#   'acs_population_adult_asianpacificislander': 1.3,
#   'vote_president2012_republican': 131115.0,
#   'acs_votingagepopulation_total': 530215.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 52.6,
#   'acs_medianincome_rank': 302.0,
#   'vote_total2014_house': 185114.0,
#   'code': 'AZ-01',
#   'votepercent_president2008_republican': 51.0,
#   'acs_population_adult_native': 21.8,
#   'votetotal_president2008': 257294.0,
#   'two_party2012_rep': 48.1,
#   'religion': 'Christian - Roman Catholic',
#   'votepercent2014_house_republican': 47.4,
#   'noncollege_white_share': 36.8,
#   'vote_house2014_democrat': 97391.0,
#   'rvotepercent_house_democrat': 50.7,
#   'party': 'Democratic',
#   'acs_population_adult_other': 1.6,
#   'vote_president2008_democrat': 123079.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 51.9,
#   'tvotetotal_president': 284973.0,
#   'vote_house2014_republican': 87723.0,
#   'first_name': 'Tom',
#   'rvotepercent_house_republican': 43.4,
#   'acs_bachelordegree_age25plus': 24.5,
#   'qvote_president_democrat': 132874.0,
#   'vote_president2008_republican': 131208.0,
#   'votepercent_president2016_democrat': 46.6},
#  {'last_name': 'McSally',
#   'votepercent_president2004_democrat': 38.0,
#   'acs_ba_rank': 141.0,
#   'votetotal2016_house': 315679.0,
#   'votepercent_president2016_republican': 44.7,
#   'acs_population_adult_white': 70.0,
#   'qvote_president_republican': 141196.0,
#   'house2_party2012_dem': 147338.0,
#   'vote_house2014_other': 104.0,
#   'first_elected': 2014,
#   'votepercent_president2004_republican': 61.0,
#   'acs_ba_white': 38.8,
#   'vote_house2016_democrat': 135873.0,
#   'votepercent_president2012_democrat': 48.4,
#   'acs_population_adult_black': 3.6,
#   'votetotal_president2012': 299691.0,
#   'house2_party2012_rep': 144884.0,
#   'birth_year': 1966,
#   'votepercent_president2000_democrat': 41.0,
#   'acs_ba_white_rank': 150.0,
#   'vote_house2016_republican': 179806.0,
#   'id': 10,
#   'votepercent_president2012_republican': 49.9,
#   'acs_population_adult_latino': 21.1,
#   'vote_president2012_democrat': 144966.0,
#   'acs_population_total': 680785.0,
#   'gender': 'Woman',
#   'votepercent_president2000_republican': 57.0,
#   'acs_medianincome': 49072.0,
#   'vote_house2016_other': 0.0,
#   'votepercent_president2008_democrat': 48.9,
#   'district': 'Arizona 2nd',
#   'acs_population_adult_asianpacificislander': 2.5,
#   'vote_president2012_republican': 149651.0,
#   'acs_votingagepopulation_total': 535575.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 49.9,
#   'acs_medianincome_rank': 326.0,
#   'vote_total2014_house': 219351.0,
#   'code': 'AZ-02',
#   'votepercent_president2008_republican': 49.8,
#   'acs_population_adult_native': 0.9,
#   'votetotal_president2008': 308531.0,
#   'two_party2012_rep': 49.6,
#   'religion': 'Christian - Protestant',
#   'votepercent2014_house_republican': 50.0,
#   'noncollege_white_share': 42.8,
#   'vote_house2014_democrat': 109543.0,
#   'rvotepercent_house_democrat': 43.0,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.8,
#   'vote_president2008_democrat': 150877.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 50.4,
#   'tvotetotal_president': 315839.0,
#   'vote_house2014_republican': 109704.0,
#   'first_name': 'Martha',
#   'rvotepercent_house_republican': 57.0,
#   'acs_bachelordegree_age25plus': 34.0,
#   'qvote_president_democrat': 156676.0,
#   'vote_president2008_republican': 153747.0,
#   'votepercent_president2016_democrat': 49.6},
#  {'last_name': 'Grijalva',
#   'votepercent_president2004_democrat': 41.0,
#   'acs_ba_rank': 416.0,
#   'votetotal2016_house': 169135.0,
#   'votepercent_president2016_republican': 32.5,
#   'acs_population_adult_white': 37.5,
#   'qvote_president_republican': 67952.0,
#   'house2_party2012_dem': 98468.0,
#   'vote_house2014_other': 51.0,
#   'first_elected': 2002,
#   'votepercent_president2004_republican': 58.0,
#   'acs_ba_white': 26.9,
#   'vote_house2016_democrat': 148973.0,
#   'votepercent_president2012_democrat': 61.4,
#   'acs_population_adult_black': 5.0,
#   'votetotal_president2012': 177248.0,
#   'house2_party2012_rep': 62663.0,
#   'birth_year': 1948,
#   'votepercent_president2000_democrat': 43.0,
#   'acs_ba_white_rank': 314.0,
#   'vote_house2016_republican': 0.0,
#   'id': 11,
#   'votepercent_president2012_republican': 36.9,
#   'acs_population_adult_latino': 51.1,
#   'vote_president2012_democrat': 108902.0,
#   'acs_population_total': 648715.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 55.0,
#   'acs_medianincome': 44224.0,
#   'vote_house2016_other': 20162.0,
#   'votepercent_president2008_democrat': 58.2,
#   'district': 'Arizona 3rd',
#   'acs_population_adult_asianpacificislander': 1.7,
#   'vote_president2012_republican': 65482.0,
#   'acs_votingagepopulation_total': 448730.0,
#   'race_ethnicity': 'Hispanic - Mexican',
#   'votepercent2014_house_democrat': 55.7,
#   'acs_medianincome_rank': 381.0,
#   'vote_total2014_house': 104428.0,
#   'code': 'AZ-03',
#   'votepercent_president2008_republican': 40.7,
#   'acs_population_adult_native': 3.5,
#   'votetotal_president2008': 176761.0,
#   'two_party2012_rep': 38.9,
#   'religion': 'Christian - Roman Catholic',
#   'votepercent2014_house_republican': 44.2,
#   'noncollege_white_share': 27.3,
#   'vote_house2014_democrat': 58192.0,
#   'rvotepercent_house_democrat': 88.1,
#   'party': 'Democratic',
#   'acs_population_adult_other': 1.3,
#   'vote_president2008_democrat': 102818.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 61.1,
#   'tvotetotal_president': 208934.0,
#   'vote_house2014_republican': 46185.0,
#   'first_name': 'Raúl',
#   'rvotepercent_house_republican': 0.0,
#   'acs_bachelordegree_age25plus': 16.5,
#   'qvote_president_democrat': 130466.0,
#   'vote_president2008_republican': 71980.0,
#   'votepercent_president2016_democrat': 62.4},
#  {'last_name': 'Gosar',
#   'votepercent_president2004_democrat': 62.0,
#   'acs_ba_rank': 398.0,
#   'votetotal2016_house': 284783.0,
#   'votepercent_president2016_republican': 67.7,
#   'acs_population_adult_white': 81.8,
#   'qvote_president_republican': 202043.0,
#   'house2_party2012_dem': 69154.0,
#   'vote_house2014_other': 7440.0,
#   'first_elected': 2010,
#   'votepercent_president2004_republican': 38.0,
#   'acs_ba_white': 20.5,
#   'vote_house2016_democrat': 81296.0,
#   'votepercent_president2012_democrat': 31.0,
#   'acs_population_adult_black': 1.7,
#   'votetotal_president2012': 258046.0,
#   'house2_party2012_rep': 162907.0,
#   'birth_year': 1958,
#   'votepercent_president2000_democrat': 63.0,
#   'acs_ba_white_rank': 414.0,
#   'vote_house2016_republican': 203487.0,
#   'id': 12,
#   'votepercent_president2012_republican': 67.2,
#   'acs_population_adult_latino': 12.6,
#   'vote_president2012_democrat': 80035.0,
#   'acs_population_total': 702085.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 35.0,
#   'acs_medianincome': 49466.0,
#   'vote_house2016_other': 0.0,
#   'votepercent_president2008_democrat': 34.4,
#   'district': 'Arizona 4th',
#   'acs_population_adult_asianpacificislander': 1.1,
#   'vote_president2012_republican': 173394.0,
#   'acs_votingagepopulation_total': 555930.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 25.8,
#   'acs_medianincome_rank': 322.0,
#   'vote_total2014_house': 175179.0,
#   'code': 'AZ-04',
#   'votepercent_president2008_republican': 64.2,
#   'acs_population_adult_native': 1.5,
#   'votetotal_president2008': 251086.0,
#   'two_party2012_rep': 70.2,
#   'religion': 'Christian - Roman Catholic',
#   'votepercent2014_house_republican': 70.0,
#   'noncollege_white_share': 64.9,
#   'vote_house2014_democrat': 45179.0,
#   'rvotepercent_house_democrat': 28.5,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.4,
#   'vote_president2008_democrat': 86346.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 29.8,
#   'tvotetotal_president': 298483.0,
#   'vote_house2014_republican': 122560.0,
#   'first_name': 'Paul',
#   'rvotepercent_house_republican': 71.5,
#   'acs_bachelordegree_age25plus': 19.2,
#   'qvote_president_democrat': 82192.0,
#   'vote_president2008_republican': 161163.0,
#   'votepercent_president2016_democrat': 27.5},
#  {'last_name': 'Biggs',
#   'votepercent_president2004_democrat': 45.0,
#   'acs_ba_rank': 119.0,
#   'votetotal2016_house': 320124.0,
#   'votepercent_president2016_republican': 57.6,
#   'acs_population_adult_white': 78.0,
#   'qvote_president_republican': 191432.0,
#   'house2_party2012_dem': 89589.0,
#   'vote_house2014_other': 0.0,
#   'first_elected': 2016,
#   'votepercent_president2004_republican': 54.0,
#   'acs_ba_white': 37.5,
#   'vote_house2016_democrat': 114940.0,
#   'votepercent_president2012_democrat': 34.6,
#   'acs_population_adult_black': 2.9,
#   'votetotal_president2012': 293748.0,
#   'house2_party2012_rep': 183470.0,
#   'birth_year': 1958,
#   'votepercent_president2000_democrat': 43.0,
#   'acs_ba_white_rank': 164.0,
#   'vote_house2016_republican': 205184.0,
#   'id': 13,
#   'votepercent_president2012_republican': 63.8,
#   'acs_population_adult_latino': 13.3,
#   'vote_president2012_democrat': 101511.0,
#   'acs_population_total': 728335.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 54.0,
#   'acs_medianincome': 71693.0,
#   'vote_house2016_other': 0.0,
#   'votepercent_president2008_democrat': 36.3,
#   'district': 'Arizona 5th',
#   'acs_population_adult_asianpacificislander': 3.7,
#   'vote_president2012_republican': 187304.0,
#   'acs_votingagepopulation_total': 528135.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 30.4,
#   'acs_medianincome_rank': 82.0,
#   'vote_total2014_house': 179463.0,
#   'code': 'AZ-05',
#   'votepercent_president2008_republican': 62.6,
#   'acs_population_adult_native': 0.8,
#   'votetotal_president2008': 286711.0,
#   'two_party2012_rep': 67.2,
#   'religion': 'Christian - Mormon',
#   'votepercent2014_house_republican': 69.6,
#   'noncollege_white_share': 48.7,
#   'vote_house2014_democrat': 54596.0,
#   'rvotepercent_house_democrat': 35.9,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.4,
#   'vote_president2008_democrat': 104014.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 32.8,
#   'tvotetotal_president': 332093.0,
#   'vote_house2014_republican': 124867.0,
#   'first_name': 'Andy',
#   'rvotepercent_house_republican': 64.1,
#   'acs_bachelordegree_age25plus': 36.0,
#   'qvote_president_democrat': 121280.0,
#   'vote_president2008_republican': 179566.0,
#   'votepercent_president2016_democrat': 36.5},
#  {'last_name': 'Schweikert',
#   'votepercent_president2004_democrat': 35.0,
#   'acs_ba_rank': 40.0,
#   'votetotal2016_house': 324444.0,
#   'votepercent_president2016_republican': 52.4,
#   'acs_population_adult_white': 81.4,
#   'qvote_president_republican': 177332.0,
#   'house2_party2012_dem': 97666.0,
#   'vote_house2014_other': 0.0,
#   'first_elected': 2010,
#   'votepercent_president2004_republican': 64.0,
#   'acs_ba_white': 48.5,
#   'vote_house2016_democrat': 122866.0,
#   'votepercent_president2012_democrat': 38.8,
#   'acs_population_adult_black': 2.5,
#   'votetotal_president2012': 313417.0,
#   'house2_party2012_rep': 179706.0,
#   'birth_year': 1962,
#   'votepercent_president2000_democrat': 37.0,
#   'acs_ba_white_rank': 72.0,
#   'vote_house2016_republican': 201578.0,
#   'id': 14,
#   'votepercent_president2012_republican': 59.5,
#   'acs_population_adult_latino': 10.3,
#   'vote_president2012_democrat': 121661.0,
#   'acs_population_total': 696790.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 61.0,
#   'acs_medianincome': 67830.0,
#   'vote_house2016_other': 0.0,
#   'votepercent_president2008_democrat': 41.2,
#   'district': 'Arizona 6th',
#   'acs_population_adult_asianpacificislander': 3.0,
#   'vote_president2012_republican': 186537.0,
#   'acs_votingagepopulation_total': 545870.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 35.1,
#   'acs_medianincome_rank': 114.0,
#   'vote_total2014_house': 199776.0,
#   'code': 'AZ-06',
#   'votepercent_president2008_republican': 57.7,
#   'acs_population_adult_native': 1.4,
#   'votetotal_president2008': 316599.0,
#   'two_party2012_rep': 64.8,
#   'religion': 'Christian - Roman Catholic',
#   'votepercent2014_house_republican': 64.9,
#   'noncollege_white_share': 41.9,
#   'vote_house2014_democrat': 70198.0,
#   'rvotepercent_house_democrat': 37.9,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.4,
#   'vote_president2008_democrat': 130426.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 35.2,
#   'tvotetotal_president': 338331.0,
#   'vote_house2014_republican': 129578.0,
#   'first_name': 'David',
#   'rvotepercent_house_republican': 62.1,
#   'acs_bachelordegree_age25plus': 45.4,
#   'qvote_president_democrat': 143571.0,
#   'vote_president2008_republican': 182747.0,
#   'votepercent_president2016_democrat': 42.4},
#  {'last_name': 'Gallego',
#   'votepercent_president2004_democrat': 57.0,
#   'acs_ba_rank': 427.0,
#   'votetotal2016_house': 158811.0,
#   'votepercent_president2016_republican': 22.6,
#   'acs_population_adult_white': 33.9,
#   'qvote_president_republican': 37232.0,
#   'house2_party2012_dem': 104489.0,
#   'vote_house2014_other': 18219.0,
#   'first_elected': 2014,
#   'votepercent_president2004_republican': 43.0,
#   'acs_ba_white': 26.5,
#   'vote_house2016_democrat': 119465.0,
#   'votepercent_president2012_democrat': 71.7,
#   'acs_population_adult_black': 12.1,
#   'votetotal_president2012': 140907.0,
#   'house2_party2012_rep': 0.0,
#   'birth_year': 1979,
#   'votepercent_president2000_democrat': 58.0,
#   'acs_ba_white_rank': 322.0,
#   'vote_house2016_republican': 39286.0,
#   'id': 15,
#   'votepercent_president2012_republican': 26.5,
#   'acs_population_adult_latino': 47.1,
#   'vote_president2012_democrat': 101028.0,
#   'acs_population_total': 615185.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 38.0,
#   'acs_medianincome': 40991.0,
#   'vote_house2016_other': 60.0,
#   'votepercent_president2008_democrat': 64.7,
#   'district': 'Arizona 7th',
#   'acs_population_adult_asianpacificislander': 2.5,
#   'vote_president2012_republican': 37353.0,
#   'acs_votingagepopulation_total': 388040.0,
#   'race_ethnicity': 'Hispanic - Mexican/Colombian',
#   'votepercent2014_house_democrat': 74.9,
#   'acs_medianincome_rank': 409.0,
#   'vote_total2014_house': 72454.0,
#   'code': 'AZ-07',
#   'votepercent_president2008_republican': 34.1,
#   'acs_population_adult_native': 2.9,
#   'votetotal_president2008': 132868.0,
#   'two_party2012_rep': 0.0,
#   'religion': 'Christian - Roman Catholic',
#   'votepercent2014_house_republican': 0.0,
#   'noncollege_white_share': 24.9,
#   'vote_house2014_democrat': 54235.0,
#   'rvotepercent_house_democrat': 75.2,
#   'party': 'Democratic',
#   'acs_population_adult_other': 1.4,
#   'vote_president2008_democrat': 85991.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 100.0,
#   'tvotetotal_president': 164399.0,
#   'vote_house2014_republican': 0.0,
#   'first_name': 'Ruben',
#   'rvotepercent_house_republican': 24.7,
#   'acs_bachelordegree_age25plus': 14.0,
#   'qvote_president_democrat': 117958.0,
#   'vote_president2008_republican': 45289.0,
#   'votepercent_president2016_democrat': 71.8},
#  {'last_name': 'Lesko',
#   'votepercent_president2004_democrat': 46.0,
#   'acs_ba_rank': 214.0,
#   'votetotal2016_house': 298971.0,
#   'votepercent_president2016_republican': 58.1,
#   'acs_population_adult_white': 76.2,
#   'qvote_president_republican': 190163.0,
#   'house2_party2012_dem': 95635.0,
#   'vote_house2014_other': 41066.0,
#   'first_elected': 2018,
#   'votepercent_president2004_republican': 53.0,
#   'acs_ba_white': 31.3,
#   'vote_house2016_democrat': 0.0,
#   'votepercent_president2012_democrat': 36.9,
#   'acs_population_adult_black': 4.2,
#   'votetotal_president2012': 291126.0,
#   'house2_party2012_rep': 172809.0,
#   'birth_year': 1958,
#   'votepercent_president2000_democrat': 46.0,
#   'acs_ba_white_rank': 245.0,
#   'vote_house2016_republican': 204942.0,
#   'id': 16,
#   'votepercent_president2012_republican': 61.7,
#   'acs_population_adult_latino': 14.6,
#   'vote_president2012_democrat': 107335.0,
#   'acs_population_total': 723400.0,
#   'gender': 'Woman',
#   'votepercent_president2000_republican': 50.0,
#   'acs_medianincome': 61754.0,
#   'vote_house2016_other': 94029.0,
#   'votepercent_president2008_democrat': 38.4,
#   'district': 'Arizona 8th',
#   'acs_population_adult_asianpacificislander': 2.7,
#   'vote_president2012_republican': 179555.0,
#   'acs_votingagepopulation_total': 551615.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 0.0,
#   'acs_medianincome_rank': 159.0,
#   'vote_total2014_house': 169776.0,
#   'code': 'AZ-08',
#   'votepercent_president2008_republican': 60.6,
#   'acs_population_adult_native': 0.7,
#   'votetotal_president2008': 288189.0,
#   'two_party2012_rep': 64.4,
#   'religion': None,
#   'votepercent2014_house_republican': 75.8,
#   'noncollege_white_share': 52.3,
#   'vote_house2014_democrat': 0.0,
#   'rvotepercent_house_democrat': 0.0,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.5,
#   'vote_president2008_democrat': 110610.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 35.6,
#   'tvotetotal_president': 327325.0,
#   'vote_house2014_republican': 128710.0,
#   'first_name': 'Debbie',
#   'rvotepercent_house_republican': 68.5,
#   'acs_bachelordegree_age25plus': 29.4,
#   'qvote_president_democrat': 120992.0,
#   'vote_president2008_republican': 174516.0,
#   'votepercent_president2016_democrat': 37.0},
#  {'last_name': 'Sinema',
#   'votepercent_president2004_democrat': 60.0,
#   'acs_ba_rank': 98.0,
#   'votetotal2016_house': 277507.0,
#   'votepercent_president2016_republican': 38.4,
#   'acs_population_adult_white': 67.9,
#   'qvote_president_republican': 109123.0,
#   'house2_party2012_dem': 121881.0,
#   'vote_house2014_other': 5612.0,
#   'first_elected': 2012,
#   'votepercent_president2004_republican': 38.0,
#   'acs_ba_white': 44.7,
#   'vote_house2016_democrat': 169055.0,
#   'votepercent_president2012_democrat': 51.1,
#   'acs_population_adult_black': 5.3,
#   'votetotal_president2012': 264563.0,
#   'house2_party2012_rep': 111630.0,
#   'birth_year': 1976,
#   'votepercent_president2000_democrat': 52.0,
#   'acs_ba_white_rank': 94.0,
#   'vote_house2016_republican': 108350.0,
#   'id': 17,
#   'votepercent_president2012_republican': 46.6,
#   'acs_population_adult_latino': 18.7,
#   'vote_president2012_democrat': 135244.0,
#   'acs_population_total': 687315.0,
#   'gender': 'Woman',
#   'votepercent_president2000_republican': 39.0,
#   'acs_medianincome': 55349.0,
#   'vote_house2016_other': 102.0,
#   'votepercent_president2008_democrat': 51.3,
#   'district': 'Arizona 9th',
#   'acs_population_adult_asianpacificislander': 3.6,
#   'vote_president2012_republican': 123263.0,
#   'acs_votingagepopulation_total': 529465.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 54.7,
#   'acs_medianincome_rank': 226.0,
#   'vote_total2014_house': 162062.0,
#   'code': 'AZ-09',
#   'votepercent_president2008_republican': 47.4,
#   'acs_population_adult_native': 2.7,
#   'votetotal_president2008': 274042.0,
#   'two_party2012_rep': 47.8,
#   'religion': 'Unaffiliated',
#   'votepercent2014_house_republican': 41.9,
#   'noncollege_white_share': 37.4,
#   'vote_house2014_democrat': 88609.0,
#   'rvotepercent_house_democrat': 60.9,
#   'party': 'Democratic',
#   'acs_population_adult_other': 1.9,
#   'vote_president2008_democrat': 140546.0,
#   'lgbtq': 'Bisexual',
#   'two_party2012_dem': 52.2,
#   'tvotetotal_president': 283863.0,
#   'vote_house2014_republican': 67841.0,
#   'first_name': 'Kyrsten',
#   'rvotepercent_house_republican': 39.0,
#   'acs_bachelordegree_age25plus': 37.5,
#   'qvote_president_democrat': 155158.0,
#   'vote_president2008_republican': 129894.0,
#   'votepercent_president2016_democrat': 54.7},
#  {'last_name': 'Crawford',
#   'votepercent_president2004_democrat': 47.0,
#   'acs_ba_rank': 416.0,
#   'votetotal2016_house': 241047.0,
#   'votepercent_president2016_republican': 65.0,
#   'acs_population_adult_white': 79.6,
#   'qvote_president_republican': 169438.0,
#   'house2_party2012_dem': 96601.0,
#   'vote_house2014_other': 8562.0,
#   'first_elected': 2010,
#   'votepercent_president2004_republican': 52.0,
#   'acs_ba_white': 17.6,
#   'vote_house2016_democrat': 0.0,
#   'votepercent_president2012_democrat': 36.3,
#   'acs_population_adult_black': 16.9,
#   'votetotal_president2012': 253460.0,
#   'house2_party2012_rep': 138800.0,
#   'birth_year': 1966,
#   'votepercent_president2000_democrat': 50.0,
#   'acs_ba_white_rank': 428.0,
#   'vote_house2016_republican': 183866.0,
#   'id': 18,
#   'votepercent_president2012_republican': 61.0,
#   'acs_population_adult_latino': 1.8,
#   'vote_president2012_democrat': 92086.0,
#   'acs_population_total': 716435.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 48.0,
#   'acs_medianincome': 40492.0,
#   'vote_house2016_other': 57181.0,
#   'votepercent_president2008_democrat': 39.2,
#   'district': 'Arkansas 1st',
#   'acs_population_adult_asianpacificislander': 0.3,
#   'vote_president2012_republican': 154549.0,
#   'acs_votingagepopulation_total': 547025.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 32.4,
#   'acs_medianincome_rank': 415.0,
#   'vote_total2014_house': 196256.0,
#   'code': 'AR-01',
#   'votepercent_president2008_republican': 58.0,
#   'acs_population_adult_native': 0.4,
#   'votetotal_president2008': 262118.0,
#   'two_party2012_rep': 59.0,
#   'religion': 'Christian - Southern Baptist',
#   'votepercent2014_house_republican': 63.3,
#   'noncollege_white_share': 65.6,
#   'vote_house2014_democrat': 63555.0,
#   'rvotepercent_house_democrat': 0.0,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.1,
#   'vote_president2008_democrat': 102670.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 41.0,
#   'tvotetotal_president': 260717.0,
#   'vote_house2014_republican': 124139.0,
#   'first_name': 'Rick',
#   'rvotepercent_house_republican': 76.3,
#   'acs_bachelordegree_age25plus': 16.5,
#   'qvote_president_democrat': 78688.0,
#   'vote_president2008_republican': 151918.0,
#   'votepercent_president2016_democrat': 30.2},
#  {'last_name': 'Hill',
#   'votepercent_president2004_democrat': 48.0,
#   'acs_ba_rank': 203.0,
#   'votetotal2016_house': 302464.0,
#   'votepercent_president2016_republican': 52.4,
#   'acs_population_adult_white': 73.7,
#   'qvote_president_republican': 160782.0,
#   'house2_party2012_dem': 113156.0,
#   'vote_house2014_other': 10780.0,
#   'first_elected': 2014,
#   'votepercent_president2004_republican': 51.0,
#   'acs_ba_white': 32.5,
#   'vote_house2016_democrat': 111347.0,
#   'votepercent_president2012_democrat': 42.9,
#   'acs_population_adult_black': 21.2,
#   'votetotal_president2012': 292515.0,
#   'house2_party2012_rep': 158175.0,
#   'birth_year': 1956,
#   'votepercent_president2000_democrat': 48.0,
#   'acs_ba_white_rank': 228.0,
#   'vote_house2016_republican': 176472.0,
#   'id': 19,
#   'votepercent_president2012_republican': 54.7,
#   'acs_population_adult_latino': 2.4,
#   'vote_president2012_democrat': 125527.0,
#   'acs_population_total': 735830.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 49.0,
#   'acs_medianincome': 49498.0,
#   'vote_house2016_other': 14645.0,
#   'votepercent_president2008_democrat': 44.3,
#   'district': 'Arkansas 2nd',
#   'acs_population_adult_asianpacificislander': 1.0,
#   'vote_president2012_republican': 160140.0,
#   'acs_votingagepopulation_total': 559250.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 43.6,
#   'acs_medianincome_rank': 321.0,
#   'vote_total2014_house': 237330.0,
#   'code': 'AR-02',
#   'votepercent_president2008_republican': 53.8,
#   'acs_population_adult_native': 0.3,
#   'votetotal_president2008': 293250.0,
#   'two_party2012_rep': 58.3,
#   'religion': 'Christian - Roman Catholic',
#   'votepercent2014_house_republican': 51.9,
#   'noncollege_white_share': 49.7,
#   'vote_house2014_democrat': 103477.0,
#   'rvotepercent_house_democrat': 36.8,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.4,
#   'vote_president2008_democrat': 129888.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 41.7,
#   'tvotetotal_president': 306974.0,
#   'vote_house2014_republican': 123073.0,
#   'first_name': 'French',
#   'rvotepercent_house_republican': 58.3,
#   'acs_bachelordegree_age25plus': 30.0,
#   'qvote_president_democrat': 127883.0,
#   'vote_president2008_republican': 157732.0,
#   'votepercent_president2016_democrat': 41.7},
#  {'last_name': 'Womack',
#   'votepercent_president2004_democrat': 36.0,
#   'acs_ba_rank': 256.0,
#   'votetotal2016_house': 280907.0,
#   'votepercent_president2016_republican': 61.9,
#   'acs_population_adult_white': 86.2,
#   'qvote_president_republican': 180921.0,
#   'house2_party2012_dem': 0.0,
#   'vote_house2014_other': 39305.0,
#   'first_elected': 2010,
#   'votepercent_president2004_republican': 62.0,
#   'acs_ba_white': 28.8,
#   'vote_house2016_democrat': 0.0,
#   'votepercent_president2012_democrat': 31.6,
#   'acs_population_adult_black': 2.9,
#   'votetotal_president2012': 257668.0,
#   'house2_party2012_rep': 186467.0,
#   'birth_year': 1957,
#   'votepercent_president2000_democrat': 37.0,
#   'acs_ba_white_rank': 286.0,
#   'vote_house2016_republican': 217192.0,
#   'id': 20,
#   'votepercent_president2012_republican': 65.5,
#   'acs_population_adult_latino': 5.9,
#   'vote_president2012_democrat': 81413.0,
#   'acs_population_total': 721855.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 60.0,
#   'acs_medianincome': 47903.0,
#   'vote_house2016_other': 63715.0,
#   'votepercent_president2008_democrat': 33.9,
#   'district': 'Arkansas 3rd',
#   'acs_population_adult_asianpacificislander': 1.9,
#   'vote_president2012_republican': 168703.0,
#   'acs_votingagepopulation_total': 532875.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 0.0,
#   'acs_medianincome_rank': 340.0,
#   'vote_total2014_house': 190935.0,
#   'code': 'AR-03',
#   'votepercent_president2008_republican': 63.9,
#   'acs_population_adult_native': 1.1,
#   'votetotal_president2008': 253566.0,
#   'two_party2012_rep': 100.0,
#   'religion': 'Christian - Southern Baptist',
#   'votepercent2014_house_republican': 79.4,
#   'noncollege_white_share': 61.3,
#   'vote_house2014_democrat': 0.0,
#   'rvotepercent_house_democrat': 0.0,
#   'party': 'Republican',
#   'acs_population_adult_other': 2.0,
#   'vote_president2008_democrat': 85866.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 0.0,
#   'tvotetotal_president': 292163.0,
#   'vote_house2014_republican': 151630.0,
#   'first_name': 'Steve',
#   'rvotepercent_house_republican': 77.3,
#   'acs_bachelordegree_age25plus': 26.9,
#   'qvote_president_democrat': 89081.0,
#   'vote_president2008_republican': 161902.0,
#   'votepercent_president2016_democrat': 30.5},
#  {'last_name': 'Westerman',
#   'votepercent_president2004_democrat': 48.0,
#   'acs_ba_rank': 420.0,
#   'votetotal2016_house': 244159.0,
#   'votepercent_president2016_republican': 64.2,
#   'acs_population_adult_white': 76.5,
#   'qvote_president_republican': 173731.0,
#   'house2_party2012_dem': 95013.0,
#   'vote_house2014_other': 7600.0,
#   'first_elected': 2014,
#   'votepercent_president2004_republican': 51.0,
#   'acs_ba_white': 17.0,
#   'vote_house2016_democrat': 0.0,
#   'votepercent_president2012_democrat': 35.9,
#   'acs_population_adult_black': 19.1,
#   'votetotal_president2012': 265825.0,
#   'house2_party2012_rep': 154149.0,
#   'birth_year': 1967,
#   'votepercent_president2000_democrat': 49.0,
#   'acs_ba_white_rank': 430.0,
#   'vote_house2016_republican': 182885.0,
#   'id': 21,
#   'votepercent_president2012_republican': 61.8,
#   'acs_population_adult_latino': 2.2,
#   'vote_president2012_democrat': 95383.0,
#   'acs_population_total': 699895.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 48.0,
#   'acs_medianincome': 39586.0,
#   'vote_house2016_other': 61274.0,
#   'votepercent_president2008_democrat': 37.4,
#   'district': 'Arkansas 4th',
#   'acs_population_adult_asianpacificislander': 0.4,
#   'vote_president2012_republican': 164352.0,
#   'acs_votingagepopulation_total': 536190.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 42.6,
#   'acs_medianincome_rank': 420.0,
#   'vote_total2014_house': 206131.0,
#   'code': 'AR-04',
#   'votepercent_president2008_republican': 59.9,
#   'acs_population_adult_native': 0.6,
#   'votetotal_president2008': 277684.0,
#   'two_party2012_rep': 61.9,
#   'religion': 'Christian - Southern Baptist',
#   'votepercent2014_house_republican': 53.7,
#   'noncollege_white_share': 63.4,
#   'vote_house2014_democrat': 87742.0,
#   'rvotepercent_house_democrat': 0.0,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.2,
#   'vote_president2008_democrat': 103886.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 38.1,
#   'tvotetotal_president': 270781.0,
#   'vote_house2014_republican': 110789.0,
#   'first_name': 'Bruce',
#   'rvotepercent_house_republican': 74.9,
#   'acs_bachelordegree_age25plus': 15.8,
#   'qvote_president_democrat': 84842.0,
#   'vote_president2008_republican': 166465.0,
#   'votepercent_president2016_democrat': 31.3},
#  {'last_name': 'LaMalfa',
#   'votepercent_president2004_democrat': 37.0,
#   'acs_ba_rank': 319.0,
#   'votetotal2016_house': 314036.0,
#   'votepercent_president2016_republican': 56.2,
#   'acs_population_adult_white': 82.7,
#   'qvote_president_republican': 176358.0,
# ...
#  {'last_name': 'Kind',
#   'votepercent_president2004_democrat': 51.0,
#   'acs_ba_rank': 285.0,
#   'votetotal2016_house': 260370.0,
#   'votepercent_president2016_republican': 49.3,
#   'acs_population_adult_white': 94.8,
#   'qvote_president_republican': 177172.0,
#   'house2_party2012_dem': 217712.0,
#   'vote_house2014_other': 253.0,
#   'first_elected': 1996,
#   'votepercent_president2004_republican': 48.0,
#   'acs_ba_white': 25.8,
#   'vote_house2016_democrat': 257401.0,
#   'votepercent_president2012_democrat': 54.8,
#   'acs_population_adult_black': 1.0,
#   'votetotal_president2012': 363335.0,
#   'house2_party2012_rep': 121713.0,
#   'birth_year': 1963,
#   'votepercent_president2000_democrat': 49.0,
#   'acs_ba_white_rank': 338.0,
#   'vote_house2016_republican': 0.0,
#   'id': 429,
#   'votepercent_president2012_republican': 43.8,
#   'acs_population_adult_latino': 1.3,
#   'vote_president2012_democrat': 199188.0,
#   'acs_population_total': 710120.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 46.0,
#   'acs_medianincome': 52154.0,
#   'vote_house2016_other': 2969.0,
#   'votepercent_president2008_democrat': 59.4,
#   'district': 'Wisconsin 3rd',
#   'acs_population_adult_asianpacificislander': 1.5,
#   'vote_president2012_republican': 159205.0,
#   'acs_votingagepopulation_total': 558335.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 56.5,
#   'acs_medianincome_rank': 264.0,
#   'vote_total2014_house': 275161.0,
#   'code': 'WI-03',
#   'votepercent_president2008_republican': 39.1,
#   'acs_population_adult_native': 0.5,
#   'votetotal_president2008': 363906.0,
#   'two_party2012_rep': 35.9,
#   'religion': 'Christian - Lutheran',
#   'votepercent2014_house_republican': 43.4,
#   'noncollege_white_share': 70.3,
#   'vote_house2014_democrat': 155368.0,
#   'rvotepercent_house_democrat': 98.9,
#   'party': 'Democratic',
#   'acs_population_adult_other': 0.8,
#   'vote_president2008_democrat': 216047.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 64.1,
#   'tvotetotal_president': 359555.0,
#   'vote_house2014_republican': 119540.0,
#   'first_name': 'Ron',
#   'rvotepercent_house_republican': 0.0,
#   'acs_bachelordegree_age25plus': 25.4,
#   'qvote_president_democrat': 160999.0,
#   'vote_president2008_republican': 142458.0,
#   'votepercent_president2016_democrat': 44.8},
#  {'last_name': 'Moore',
#   'votepercent_president2004_democrat': 70.0,
#   'acs_ba_rank': 249.0,
#   'votetotal2016_house': 286909.0,
#   'votepercent_president2016_republican': 21.8,
#   'acs_population_adult_white': 52.6,
#   'qvote_president_republican': 67287.0,
#   'house2_party2012_dem': 235257.0,
#   'vote_house2014_other': 7357.0,
#   'first_elected': 2004,
#   'votepercent_president2004_republican': 30.0,
#   'acs_ba_white': 39.9,
#   'vote_house2016_democrat': 220181.0,
#   'votepercent_president2012_democrat': 75.3,
#   'acs_population_adult_black': 32.8,
#   'votetotal_president2012': 356355.0,
#   'house2_party2012_rep': 80787.0,
#   'birth_year': 1951,
#   'votepercent_president2000_democrat': 66.0,
#   'acs_ba_white_rank': 138.0,
#   'vote_house2016_republican': 0.0,
#   'id': 430,
#   'votepercent_president2012_republican': 23.8,
#   'acs_population_adult_latino': 9.7,
#   'vote_president2012_democrat': 268440.0,
#   'acs_population_total': 672620.0,
#   'gender': 'Woman',
#   'votepercent_president2000_republican': 30.0,
#   'acs_medianincome': 41816.0,
#   'vote_house2016_other': 66728.0,
#   'votepercent_president2008_democrat': 74.4,
#   'district': 'Wisconsin 4th',
#   'acs_population_adult_asianpacificislander': 2.6,
#   'vote_president2012_republican': 84751.0,
#   'acs_votingagepopulation_total': 493865.0,
#   'race_ethnicity': 'Black - African-American',
#   'votepercent2014_house_democrat': 70.2,
#   'acs_medianincome_rank': 398.0,
#   'vote_total2014_house': 254892.0,
#   'code': 'WI-04',
#   'votepercent_president2008_republican': 24.6,
#   'acs_population_adult_native': 0.5,
#   'votetotal_president2008': 342054.0,
#   'two_party2012_rep': 25.6,
#   'religion': 'Christian - Baptist',
#   'votepercent2014_house_republican': 26.9,
#   'noncollege_white_share': 31.6,
#   'vote_house2014_democrat': 179045.0,
#   'rvotepercent_house_democrat': 76.7,
#   'party': 'Democratic',
#   'acs_population_adult_other': 1.8,
#   'vote_president2008_democrat': 254531.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 74.4,
#   'tvotetotal_president': 308575.0,
#   'vote_house2014_republican': 68490.0,
#   'first_name': 'Gwen',
#   'rvotepercent_house_republican': 0.0,
#   'acs_bachelordegree_age25plus': 27.4,
#   'qvote_president_democrat': 228226.0,
#   'vote_president2008_republican': 84194.0,
#   'votepercent_president2016_democrat': 74.0},
#  {'last_name': 'Sensenbrenner',
#   'votepercent_president2004_democrat': 36.0,
#   'acs_ba_rank': 108.0,
#   'votetotal2016_house': 390844.0,
#   'votepercent_president2016_republican': 57.4,
#   'acs_population_adult_white': 92.4,
#   'qvote_president_republican': 229325.0,
#   'house2_party2012_dem': 118478.0,
#   'vote_house2014_other': 476.0,
#   'first_elected': 1978,
#   'votepercent_president2004_republican': 63.0,
#   'acs_ba_white': 36.9,
#   'vote_house2016_democrat': 114477.0,
#   'votepercent_president2012_democrat': 37.7,
#   'acs_population_adult_black': 1.8,
#   'votetotal_president2012': 419191.0,
#   'house2_party2012_rep': 250335.0,
#   'birth_year': 1943,
#   'votepercent_president2000_democrat': 35.0,
#   'acs_ba_white_rank': 172.0,
#   'vote_house2016_republican': 260706.0,
#   'id': 431,
#   'votepercent_president2012_republican': 61.3,
#   'acs_population_adult_latino': 3.3,
#   'vote_president2012_democrat': 158226.0,
#   'acs_population_total': 702210.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 62.0,
#   'acs_medianincome': 68162.0,
#   'vote_house2016_other': 15661.0,
#   'votepercent_president2008_democrat': 41.8,
#   'district': 'Wisconsin 5th',
#   'acs_population_adult_asianpacificislander': 1.4,
#   'vote_president2012_republican': 257017.0,
#   'acs_votingagepopulation_total': 546590.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 30.4,
#   'acs_medianincome_rank': 112.0,
#   'vote_total2014_house': 332826.0,
#   'code': 'WI-05',
#   'votepercent_president2008_republican': 57.2,
#   'acs_population_adult_native': 0.2,
#   'votetotal_president2008': 403822.0,
#   'two_party2012_rep': 67.9,
#   'religion': 'Christian - Roman Catholic',
#   'votepercent2014_house_republican': 69.5,
#   'noncollege_white_share': 58.3,
#   'vote_house2014_democrat': 101190.0,
#   'rvotepercent_house_democrat': 29.3,
#   'party': 'Republican',
#   'acs_population_adult_other': 0.8,
#   'vote_president2008_democrat': 168644.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 32.1,
#   'tvotetotal_president': 399261.0,
#   'vote_house2014_republican': 231160.0,
#   'first_name': 'Jim',
#   'rvotepercent_house_republican': 66.7,
#   'acs_bachelordegree_age25plus': 36.9,
#   'qvote_president_democrat': 148900.0,
#   'vote_president2008_republican': 230861.0,
#   'votepercent_president2016_democrat': 37.3},
#  {'last_name': 'Grothman',
#   'votepercent_president2004_democrat': 43.0,
#   'acs_ba_rank': 268.0,
#   'votetotal2016_house': 357183.0,
#   'votepercent_president2016_republican': 55.7,
#   'acs_population_adult_white': 93.6,
#   'qvote_president_republican': 203433.0,
#   'house2_party2012_dem': 135921.0,
#   'vote_house2014_other': 7054.0,
#   'first_elected': 2014,
#   'votepercent_president2004_republican': 56.0,
#   'acs_ba_white': 26.8,
#   'vote_house2016_democrat': 133072.0,
#   'votepercent_president2012_democrat': 45.8,
#   'acs_population_adult_black': 1.5,
#   'votetotal_president2012': 382295.0,
#   'house2_party2012_rep': 223460.0,
#   'birth_year': 1955,
#   'votepercent_president2000_democrat': 42.0,
#   'acs_ba_white_rank': 316.0,
#   'vote_house2016_republican': 204147.0,
#   'id': 432,
#   'votepercent_president2012_republican': 53.1,
#   'acs_population_adult_latino': 2.3,
#   'vote_president2012_democrat': 174988.0,
#   'acs_population_total': 698950.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 53.0,
#   'acs_medianincome': 57129.0,
#   'vote_house2016_other': 19964.0,
#   'votepercent_president2008_democrat': 49.4,
#   'district': 'Wisconsin 6th',
#   'acs_population_adult_asianpacificislander': 1.4,
#   'vote_president2012_republican': 202979.0,
#   'acs_votingagepopulation_total': 546370.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 40.9,
#   'acs_medianincome_rank': 209.0,
#   'vote_total2014_house': 299033.0,
#   'code': 'WI-06',
#   'votepercent_president2008_republican': 49.3,
#   'acs_population_adult_native': 0.5,
#   'votetotal_president2008': 375245.0,
#   'two_party2012_rep': 62.2,
#   'religion': 'Christian - Lutheran',
#   'votepercent2014_house_republican': 56.8,
#   'noncollege_white_share': 68.5,
#   'vote_house2014_democrat': 122212.0,
#   'rvotepercent_house_democrat': 37.3,
#   'party': 'Republican',
#   'acs_population_adult_other': 0.7,
#   'vote_president2008_democrat': 185438.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 37.8,
#   'tvotetotal_president': 365442.0,
#   'vote_house2014_republican': 169767.0,
#   'first_name': 'Glenn',
#   'rvotepercent_house_republican': 57.2,
#   'acs_bachelordegree_age25plus': 26.4,
#   'qvote_president_democrat': 141917.0,
#   'vote_president2008_republican': 184985.0,
#   'votepercent_president2016_democrat': 38.8},
#  {'last_name': 'Duffy',
#   'votepercent_president2004_democrat': 50.0,
#   'acs_ba_rank': 329.0,
#   'votetotal2016_house': 362271.0,
#   'votepercent_president2016_republican': 57.7,
#   'acs_population_adult_white': 94.6,
#   'qvote_president_republican': 213467.0,
#   'house2_party2012_dem': 157524.0,
#   'vote_house2014_other': 3763.0,
#   'first_elected': 2010,
#   'votepercent_president2004_republican': 49.0,
#   'acs_ba_white': 23.4,
#   'vote_house2016_democrat': 138643.0,
#   'votepercent_president2012_democrat': 47.8,
#   'acs_population_adult_black': 0.5,
#   'votetotal_president2012': 373876.0,
#   'house2_party2012_rep': 201720.0,
#   'birth_year': 1971,
#   'votepercent_president2000_democrat': 48.0,
#   'acs_ba_white_rank': 386.0,
#   'vote_house2016_republican': 223418.0,
#   'id': 433,
#   'votepercent_president2012_republican': 50.9,
#   'acs_population_adult_latino': 1.2,
#   'vote_president2012_democrat': 178841.0,
#   'acs_population_total': 701860.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 47.0,
#   'acs_medianincome': 51738.0,
#   'vote_house2016_other': 210.0,
#   'votepercent_president2008_democrat': 53.2,
#   'district': 'Wisconsin 7th',
#   'acs_population_adult_asianpacificislander': 1.0,
#   'vote_president2012_republican': 190364.0,
#   'acs_votingagepopulation_total': 546440.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 39.4,
#   'acs_medianincome_rank': 271.0,
#   'vote_total2014_house': 286603.0,
#   'code': 'WI-07',
#   'votepercent_president2008_republican': 45.3,
#   'acs_population_adult_native': 1.8,
#   'votetotal_president2008': 371936.0,
#   'two_party2012_rep': 56.2,
#   'religion': 'Christian - Roman Catholic',
#   'votepercent2014_house_republican': 59.3,
#   'noncollege_white_share': 72.5,
#   'vote_house2014_democrat': 112949.0,
#   'rvotepercent_house_democrat': 38.3,
#   'party': 'Republican',
#   'acs_population_adult_other': 0.9,
#   'vote_president2008_democrat': 197706.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 43.8,
#   'tvotetotal_president': 369841.0,
#   'vote_house2014_republican': 169891.0,
#   'first_name': 'Sean',
#   'rvotepercent_house_republican': 61.7,
#   'acs_bachelordegree_age25plus': 23.1,
#   'qvote_president_democrat': 137874.0,
#   'vote_president2008_republican': 168540.0,
#   'votepercent_president2016_democrat': 37.3},
#  {'last_name': 'Gallagher',
#   'votepercent_president2004_democrat': 44.0,
#   'acs_ba_rank': 285.0,
#   'votetotal2016_house': 363780.0,
#   'votepercent_president2016_republican': 56.2,
#   'acs_population_adult_white': 92.3,
#   'qvote_president_republican': 207620.0,
#   'house2_party2012_dem': 156287.0,
#   'vote_house2014_other': 150.0,
#   'first_elected': 2016,
#   'votepercent_president2004_republican': 55.0,
#   'acs_ba_white': 26.0,
#   'vote_house2016_democrat': 135682.0,
#   'votepercent_president2012_democrat': 47.6,
#   'acs_population_adult_black': 1.0,
#   'votetotal_president2012': 372886.0,
#   'house2_party2012_rep': 198874.0,
#   'birth_year': 1984,
#   'votepercent_president2000_democrat': 43.0,
#   'acs_ba_white_rank': 334.0,
#   'vote_house2016_republican': 227892.0,
#   'id': 434,
#   'votepercent_president2012_republican': 51.3,
#   'acs_population_adult_latino': 2.2,
#   'vote_president2012_democrat': 177346.0,
#   'acs_population_total': 707485.0,
#   'gender': 'Man',
#   'votepercent_president2000_republican': 52.0,
#   'acs_medianincome': 57888.0,
#   'vote_house2016_other': 206.0,
#   'votepercent_president2008_democrat': 53.7,
#   'district': 'Wisconsin 8th',
#   'acs_population_adult_asianpacificislander': 1.4,
#   'vote_president2012_republican': 191127.0,
#   'acs_votingagepopulation_total': 541425.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 34.9,
#   'acs_medianincome_rank': 198.0,
#   'vote_total2014_house': 290048.0,
#   'code': 'WI-08',
#   'votepercent_president2008_republican': 45.0,
#   'acs_population_adult_native': 2.1,
#   'votetotal_president2008': 362769.0,
#   'two_party2012_rep': 56.0,
#   'religion': 'Christian - Roman Catholic',
#   'votepercent2014_house_republican': 65.0,
#   'noncollege_white_share': 68.3,
#   'vote_house2014_democrat': 101345.0,
#   'rvotepercent_house_democrat': 37.3,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.0,
#   'vote_president2008_democrat': 194663.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 44.0,
#   'tvotetotal_president': 369562.0,
#   'vote_house2014_republican': 188553.0,
#   'first_name': 'Mike',
#   'rvotepercent_house_republican': 62.6,
#   'acs_bachelordegree_age25plus': 25.4,
#   'qvote_president_democrat': 142677.0,
#   'vote_president2008_republican': 163343.0,
#   'votepercent_president2016_democrat': 38.6},
#  {'last_name': 'Cheney',
#   'votepercent_president2004_democrat': 29.0,
#   'acs_ba_rank': 253.0,
#   'votetotal2016_house': 251776.0,
#   'votepercent_president2016_republican': 70.1,
#   'acs_population_adult_white': 88.4,
#   'qvote_president_republican': 174419.0,
#   'house2_party2012_dem': 57573.0,
#   'vote_house2014_other': 14259.0,
#   'first_elected': 2016,
#   'votepercent_president2004_republican': 69.0,
#   'acs_ba_white': 28.5,
#   'vote_house2016_democrat': 75466.0,
#   'votepercent_president2012_democrat': 28.0,
#   'acs_population_adult_black': 0.9,
#   'votetotal_president2012': 247026.0,
#   'house2_party2012_rep': 166452.0,
#   'birth_year': 1966,
#   'votepercent_president2000_democrat': 28.0,
#   'acs_ba_white_rank': 292.0,
#   'vote_house2016_republican': 156176.0,
#   'id': 435,
#   'votepercent_president2012_republican': 69.2,
#   'acs_population_adult_latino': 6.9,
#   'vote_president2012_democrat': 69286.0,
#   'acs_population_total': 570345.0,
#   'gender': 'Woman',
#   'votepercent_president2000_republican': 69.0,
#   'acs_medianincome': 59882.0,
#   'vote_house2016_other': 20134.0,
#   'votepercent_president2008_democrat': 32.7,
#   'district': 'Wyoming At-Large',
#   'acs_population_adult_asianpacificislander': 0.6,
#   'vote_president2012_republican': 170962.0,
#   'acs_votingagepopulation_total': 432375.0,
#   'race_ethnicity': 'White - Non-Hispanic',
#   'votepercent2014_house_democrat': 22.9,
#   'acs_medianincome_rank': 185.0,
#   'vote_total2014_house': 165100.0,
#   'code': 'WY-00',
#   'votepercent_president2008_republican': 65.2,
#   'acs_population_adult_native': 1.8,
#   'votetotal_president2008': 253137.0,
#   'two_party2012_rep': 74.3,
#   'religion': 'Christian - Methodist',
#   'votepercent2014_house_republican': 68.5,
#   'noncollege_white_share': 63.1,
#   'vote_house2014_democrat': 37803.0,
#   'rvotepercent_house_democrat': 30.0,
#   'party': 'Republican',
#   'acs_population_adult_other': 1.5,
#   'vote_president2008_democrat': 82868.0,
#   'lgbtq': 'No',
#   'two_party2012_dem': 25.7,
#   'tvotetotal_president': 248945.0,
#   'vote_house2014_republican': 113038.0,
#   'first_name': 'Liz',
#   'rvotepercent_house_republican': 62.0,
#   'acs_bachelordegree_age25plus': 27.1,
#   'qvote_president_democrat': 55973.0,
#   'vote_president2008_republican': 164958.0,
#   'votepercent_president2016_democrat': 22.5}]

# %%
json.dumps(results[0])
# Out:
# '{"last_name": "Byrne", "votepercent_president2004_democrat": 35.0, "acs_ba_rank": 308.0, "votetotal2016_house": 215893.0, "votepercent_president2016_republican": 63.5, "acs_population_adult_white": 68.7, "qvote_president_republican": 192634.0, "house2_party2012_dem": 0.0, "vote_house2014_other": 198.0, "first_elected": 2016, "votepercent_president2004_republican": 64.0, "acs_ba_white": 27.7, "vote_house2016_democrat": 0.0, "votepercent_president2012_democrat": 37.4, "acs_population_adult_black": 26.5, "votetotal_president2012": 298837.0, "house2_party2012_rep": 196374.0, "birth_year": 1955, "votepercent_president2000_democrat": 38.0, "acs_ba_white_rank": 303.0, "vote_house2016_republican": 208083.0, "id": 1, "votepercent_president2012_republican": 61.8, "acs_population_adult_latino": 1.8, "vote_president2012_democrat": 111735.0, "acs_population_total": 688770.0, "gender": "Man", "votepercent_president2000_republican": 60.0, "acs_medianincome": 47083.0, "vote_house2016_other": 7810.0, "votepercent_president2008_democrat": 38.5, "district": "Alabama 1st", "acs_population_adult_asianpacificislander": 0.9, "vote_president2012_republican": 184786.0, "acs_votingagepopulation_total": 526450.0, "race_ethnicity": "White - Non-Hispanic", "votepercent2014_house_democrat": 31.7, "acs_medianincome_rank": 350.0, "vote_total2014_house": 152234.0, "code": "AL-01", "votepercent_president2008_republican": 60.9, "acs_population_adult_native": 1.0, "votetotal_president2008": 301556.0, "two_party2012_rep": 100.0, "religion": "Christian - Episcopalian", "votepercent2014_house_republican": 68.2, "noncollege_white_share": 49.6, "vote_house2014_democrat": 48278.0, "rvotepercent_house_democrat": 0.0, "party": "Republican", "acs_population_adult_other": 1.1, "vote_president2008_democrat": 115975.0, "lgbtq": "No", "two_party2012_dem": 0.0, "tvotetotal_president": 303478.0, "vote_house2014_republican": 103758.0, "first_name": "Bradley", "rvotepercent_house_republican": 96.4, "acs_bachelordegree_age25plus": 24.0, "qvote_president_democrat": 103364.0, "vote_president2008_republican": 183753.0, "votepercent_president2016_democrat": 34.1}'

# %%
election2 = session.query(Election).filter_by(code='IN-01').all()

# %%
print(election2[0].id)
# Out:
# 151

# %%
for item in election2:
    temp = item.__dict__
    v2000d = temp["votepercent_president2000_democrat"]
    v2000r = temp["votepercent_president2000_republican"]
    v2004d = temp["votepercent_president2004_democrat"]
    v2004r = temp["votepercent_president2004_republican"]
    v2008d = temp["votepercent_president2008_democrat"]
    v2008r = temp["votepercent_president2008_republican"]
    v2012d = temp["votepercent_president2012_democrat"]
    v2012r = temp["votepercent_president2012_republican"]
    v2016d = temp["votepercent_president2016_democrat"]
    v2016r = temp["votepercent_president2016_republican"]

    graph_data = [{"date":"00-Jan-01", "Democrat":v2000d, "Republican":v2000r},
    {"date":"04-Jan-01", "Democrat":v2004d, "Republican":v2004r},
    {"date":"08-Jan-01", "Democrat":v2008d, "Republican":v2008r},
    {"date":"12-Jan-01", "Democrat":v2012d, "Republican":v2012r},
    {"date":"16-Jan-01", "Democrat":v2016d, "Republican":v2016r}]

# %%
graph_data
# Out:
# [{'date': '00-Jan-01', 'Democrat': 33.0, 'Republican': 66.0},
#  {'date': '04-Jan-01', 'Democrat': 31.0, 'Republican': 68.0},
#  {'date': '08-Jan-01', 'Democrat': 63.3, 'Republican': 35.8},
#  {'date': '12-Jan-01', 'Democrat': 61.2, 'Republican': 37.4},
#  {'date': '16-Jan-01', 'Democrat': 54.1, 'Republican': 41.5}]

# %%
session.close()
