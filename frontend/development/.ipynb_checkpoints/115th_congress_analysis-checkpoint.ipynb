# %% [markdown]
# #Analysis of 115th Congress
# ##template created by Erin Wills

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_excel("../data/115th_congress_by_district.xlsx")

# %%
df.head()
# Out:
#       District   Code         Party Incumbent Name-First Incumbent Name-Last  \
# 0   Nationwide    USA  236R-192D-7V                  NaN                 NaN
# 1  Alabama 1st  AL-01    Republican              Bradley               Byrne
# 2  Alabama 2nd  AL-02    Republican               Martha                Roby
# 3  Alabama 3rd  AL-03    Republican                 Mike              Rogers
# 4  Alabama 4th  AL-04    Republican               Robert            Aderholt
#
#   Pronunciation Guide-Phonetic  Pronunciation Guide-IPA First Elected  \
# 0                          NaN                      NaN           NaN
# 1             (BRADD-lee BURN)          /'bɹæd.li bɜɹn/          2016
# 2           (MAR-thuh ROH-bee)        /'mɑɹ.θə 'ɹoʊ.bi/          2010
# 3              (MIKE RAH-jerz)         /maɪk 'ɹɑ.dʒəɹz/          2002
# 4       (RAH-bert ADD-er-holt)  /'ɹɑ.bəɹt 'æ.ɾəɹ.hoʊlt/          1996
#
#   Birth Year Gender  ...  \
# 0        NaN    NaN  ...
# 1       1955    Man  ...
# 2       1976  Woman  ...
# 3       1958    Man  ...
# 4       1965    Man  ...
#
#   Census Total Population (Includes Latinos of Any Race)-Asian and Pacific Islander  \
# 0                                           14950101
# 1                                               9296
# 2                                               7900
# 3                                               7923
# 4                                               3200
#
#   Census Total Population (Includes Latinos of Any Race)-Native American  \
# 0                                            2259941
# 1                                               7644
# 2                                               3072
# 3                                               2117
# 4                                               5218
#
#   Census Total Population (Includes Latinos of Any Race)-Other  \
# 0                                            6749678
# 1                                               9350
# 2                                               9953
# 3                                               9057
# 4                                               9616
#
#   Census Voting Age Population (Includes Latinos of Any Race)-Total  \
# 0                                          234562019
# 1                                             515948
# 2                                             522837
# 3                                             523481
# 4                                             521081
#
#    Census Voting Age Population (Includes Latinos of Any Race)-White  \
# 0                                          157100379
# 1                                             353347
# 2                                             347855
# 3                                             374072
# 4                                             452704
#
#    Census Voting Age Population (Includes Latinos of Any Race)-Black  \
# 0                                           27379039
# 1                                             132261
# 2                                             145568
# 3                                             125248
# 4                                              34104
#
#    Census Voting Age Population (Includes Latinos of Any Race)-Latino  \
# 0                                           33345990
# 1                                              12904
# 2                                              15912
# 3                                              11783
# 4                                              22579
#
#    Census Voting Age Population (Includes Latinos of Any Race)-Asian and Pacific Islander  \
# 0                                           11637156
# 1                                               6918
# 2                                               6059
# 3                                               5992
# 4                                               2369
#
#    Census Voting Age Population (Includes Latinos of Any Race)-Native American  \
# 0                                            1607263
# 1                                               5524
# 2                                               2371
# 3                                               1705
# 4                                               3870
#
#    Census Voting Age Population (Includes Latinos of Any Race)-Other
# 0                                            3704719
# 1                                               4994
# 2                                               5072
# 3                                               4681
# 4                                               5455
#
# [5 rows x 100 columns]

# %%
df['Gender'].value_counts()
# Out:
# Man      343
# Woman     84
# Name: Gender, dtype: int64

# %%
df["Party"].unique()
# Out:
# array(['236R-192D-7V', 'Republican', 'Democratic', 'Vacant (R)',
#        'Vacant (D)'], dtype=object)
